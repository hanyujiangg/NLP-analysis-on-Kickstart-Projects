# %% [markdown]
# ## Content-based recommender for kickstarter projects

# %%
# run this statement only once to install Rake
# !pip install rake_nltk
# Out:
# Requirement already satisfied: rake_nltk in c:\users\raymond koh\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: nltk in c:\users\raymond koh\anaconda3\lib\site-packages (from rake_nltk) (3.4.4)
# Requirement already satisfied: six in c:\users\raymond koh\anaconda3\lib\site-packages (from nltk->rake_nltk) (1.12.0)

# %%
import numpy as np
import pandas as pd
from rake_nltk import Rake
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

import re, nltk, gensim
from nltk.tokenize import ToktokTokenizer
from nltk.stem import wordnet
from nltk.corpus import stopwords
from string import punctuation

# %% [markdown]
# ### Step 1: Read in and analyse the data

# %%
import pandas as pd
import glob

path = r'./data/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)



# df = pd.read_csv('Kickstarter057.csv')

df = frame
df.head()
# Out:
#    backers_count                                              blurb  \
# 0             27  A student design build studio blurring the bou...
# 1             54  A patch commemorating the SN8 flight from Boca...
# 2             63  We are creating TRM movie posters for distribu...
# 3             26  A video performance piece for the self-designe...
# 4              2  Providing young artists with creative sponsors...
#
#                                             category  \
# 0  {"id":25,"name":"Sculpture","slug":"art/sculpt...
# 1  {"id":1,"name":"Art","slug":"art","position":1...
# 2  {"id":21,"name":"Digital Art","slug":"art/digi...
# 3  {"id":24,"name":"Performance Art","slug":"art/...
# 4  {"id":288,"name":"Installations","slug":"art/i...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      1369      US        the United States  1334085321
# 1                      1229      US        the United States  1602983631
# 2                      1637      US        the United States  1341415158
# 3                      2750      US        the United States  1307480670
# 4                        75      US        the United States  1519066595
#
#                                              creator currency currency_symbol  \
# 0  {"id":1709491227,"name":"Kevin Taylor","is_reg...      USD               $
# 1  {"id":1475027416,"name":"Liem Bahneman","slug"...      USD               $
# 2  {"id":80857009,"name":"Erik van Ingen","is_reg...      USD               $
# 3  {"id":744741310,"name":"Melissa Basaran (delet...      USD               $
# 4  {"id":1773775377,"name":"Chelsey Everest Eiel"...      USD               $
#
#    ...  state_changed_at static_usd_rate  \
# 0  ...        1335762019             1.0
# 1  ...        1608170400             1.0
# 2  ...        1342238341             1.0
# 3  ...        1310767233             1.0
# 4  ...        1522253573             1.0
#
#                                                 urls  usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...       1369.0
# 1  {"web":{"project":"https://www.kickstarter.com...       1229.0
# 2  {"web":{"project":"https://www.kickstarter.com...       1637.5
# 3  {"web":{"project":"https://www.kickstarter.com...       2750.0
# 4  {"web":{"project":"https://www.kickstarter.com...         75.0
#
#         usd_type  Unnamed: 38             Unnamed: 39  \
# 0  international     {"id":25        name:"Sculpture"
# 1  international      {"id":1              name:"Art"
# 2  international     {"id":21      name:"Digital Art"
# 3  international     {"id":24  name:"Performance Art"
# 4  international    {"id":288    name:"Installations"
#
#                   Unnamed: 40          Unnamed: 41  Final Main
# 0        slug:"art/sculpture"        art/sculpture         art
# 1                  slug:"art"                  art         art
# 2      slug:"art/digital art"      art/digital art         art
# 3  slug:"art/performance art"  art/performance art         art
# 4    slug:"art/installations"    art/installations         art
#
# [5 rows x 43 columns]

# %%
def extract_cat(text):
    text = text.split(",")
    
    text = text[1] + " " +text[2]
    

    text = text.replace ("/", " ")
    
    
    text = text.replace ("name", "")
    text = text.replace ("slug", "")
    
    text = text.replace ('"', "")
    text = text.replace ('{', "")
    text = text.replace (':', "")
    
    text = text.lower()
    text = re.sub(r"\'\n", " ", text)
    text = re.sub(r"\'\xa0", " ", text)
    text = re.sub('\s+', ' ', text) # matches all whitespace characters
    text = text.strip(' ')
    return text



df['category'] = df['category'].apply(lambda x: extract_cat(x))


df.head()
# Out:
#    backers_count                                              blurb  \
# 0             27  A student design build studio blurring the bou...
# 1             54  A patch commemorating the SN8 flight from Boca...
# 2             63  We are creating TRM movie posters for distribu...
# 3             26  A video performance piece for the self-designe...
# 4              2  Providing young artists with creative sponsors...
#
#                               category  converted_pledged_amount country  \
# 0              sculpture art sculpture                      1369      US
# 1                              art art                      1229      US
# 2          digital art art digital art                      1637      US
# 3  performance art art performance art                      2750      US
# 4      installations art installations                        75      US
#
#   country_displayable_name  created_at  \
# 0        the United States  1334085321
# 1        the United States  1602983631
# 2        the United States  1341415158
# 3        the United States  1307480670
# 4        the United States  1519066595
#
#                                              creator currency currency_symbol  \
# 0  {"id":1709491227,"name":"Kevin Taylor","is_reg...      USD               $
# 1  {"id":1475027416,"name":"Liem Bahneman","slug"...      USD               $
# 2  {"id":80857009,"name":"Erik van Ingen","is_reg...      USD               $
# 3  {"id":744741310,"name":"Melissa Basaran (delet...      USD               $
# 4  {"id":1773775377,"name":"Chelsey Everest Eiel"...      USD               $
#
#    ...  state_changed_at static_usd_rate  \
# 0  ...        1335762019             1.0
# 1  ...        1608170400             1.0
# 2  ...        1342238341             1.0
# 3  ...        1310767233             1.0
# 4  ...        1522253573             1.0
#
#                                                 urls  usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...       1369.0
# 1  {"web":{"project":"https://www.kickstarter.com...       1229.0
# 2  {"web":{"project":"https://www.kickstarter.com...       1637.5
# 3  {"web":{"project":"https://www.kickstarter.com...       2750.0
# 4  {"web":{"project":"https://www.kickstarter.com...         75.0
#
#         usd_type  Unnamed: 38             Unnamed: 39  \
# 0  international     {"id":25        name:"Sculpture"
# 1  international      {"id":1              name:"Art"
# 2  international     {"id":21      name:"Digital Art"
# 3  international     {"id":24  name:"Performance Art"
# 4  international    {"id":288    name:"Installations"
#
#                   Unnamed: 40          Unnamed: 41  Final Main
# 0        slug:"art/sculpture"        art/sculpture         art
# 1                  slug:"art"                  art         art
# 2      slug:"art/digital art"      art/digital art         art
# 3  slug:"art/performance art"  art/performance art         art
# 4    slug:"art/installations"    art/installations         art
#
# [5 rows x 43 columns]

# %%
df = df[['name','category','blurb']]
df.head()
# Out:
#                                            name  \
# 0                                     Bird Wall
# 1  SpaceX SN8 Starship Prototype 12km Hop Patch
# 2                 "The Real Maine" movie poster
# 3         Voicing Islam Video Performance Piece
# 4           The Daughters of Revolution Project
#
#                               category  \
# 0              sculpture art sculpture
# 1                              art art
# 2          digital art art digital art
# 3  performance art art performance art
# 4      installations art installations
#
#                                                blurb
# 0  A student design build studio blurring the bou...
# 1  A patch commemorating the SN8 flight from Boca...
# 2  We are creating TRM movie posters for distribu...
# 3  A video performance piece for the self-designe...
# 4  Providing young artists with creative sponsors...

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
import re
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 

def preprocess(sentence):
    sentence=str(sentence)
    sentence = sentence.lower()
    sentence=sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url=re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    stem_words=[stemmer.stem(w) for w in filtered_words]
    lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
    return " ".join(filtered_words)


df['blurb']=df['blurb'].map(lambda s:preprocess(s)) 
df.head()
# Out:
# C:\Users\Raymond Koh\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                            name  \
# 0                                     Bird Wall
# 1  SpaceX SN8 Starship Prototype 12km Hop Patch
# 2                 "The Real Maine" movie poster
# 3         Voicing Islam Video Performance Piece
# 4           The Daughters of Revolution Project
#
#                               category  \
# 0              sculpture art sculpture
# 1                              art art
# 2          digital art art digital art
# 3  performance art art performance art
# 4      installations art installations
#
#                                                blurb
# 0  student design build studio blurring boundarie...
# 1              patch commemorating flight boca chica
# 2  creating trm movie posters distribution opport...
# 3  video performance piece self designed voicing ...
# 4  providing young artists creative sponsors part...

# %%
dfcat = df['category']

dfcat.head 

num_dfcat = len(dfcat)

#print(num_dfcat)

from nltk.tokenize import word_tokenize

dfcat = dfcat.apply(word_tokenize)
dfcat.head()
# Out:
# 0                  [sculpture, art, sculpture]
# 1                                   [art, art]
# 2            [digital, art, art, digital, art]
# 3    [performance, art, art, performance, art]
# 4          [installations, art, installations]
# Name: category, dtype: object

# %%
from gensim import corpora

dictionary = corpora.Dictionary(dfcat)

print(dictionary)
# Out:
# Dictionary(96 unique tokens: ['art', 'sculpture', 'digital', 'performance', 'installations']...)

# %%
# Convert all documents to TF Vectors
all_tf_vectors = [dictionary.doc2bow(doc) for doc in dfcat]

# %%
#Label the trained data.

all_data_as_dict = [{id:1 for (id, tf_value) in vec} for vec in all_tf_vectors]

#print(type(all_data_as_dict))
#print(all_data_as_dict)

all_arts = [(d, 'ARTS') for d in all_data_as_dict[0:12]]
all_paintings = [(d, 'PAINTINGS') for d in all_data_as_dict[13:20]]

# %%
#Generate the trained classifier
classifier = nltk.NaiveBayesClassifier.train(all_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f1805d875bd7> in <module>
#       1 #Generate the trained classifier
# ----> 2 classifier = nltk.NaiveBayesClassifier.train(all_data)
#
# NameError: name 'all_data' is not defined

# %%
test_doc = all_data_as_dict[0] #35 is crime article. Until 99 are all crime
print(classifier.classify(test_doc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-023a0704ea6c> in <module>
#       1 test_doc = all_data_as_dict[0] #35 is crime article. Until 99 are all crime
# ----> 2 print(classifier.classify(test_doc))
#
# NameError: name 'classifier' is not defined
